# %%
import utils

# %%
project_data = "playground-series-s5e12.zip"

# %%
utils.extract_from_zip(project_data)

# %% [markdown]
# ## Read the data

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data_dir = Path(project_data.split('.')[0])
train_data = pd.read_csv(data_dir / "train.csv")
test_data = pd.read_csv(data_dir / "test.csv")

# %%
train_data.shape
# Out:
# (700000, 26)

# %%
train_data.head().T
# Out:
#                                                0             1             2  \
# id                                             0             1             2
# age                                           31            50            32
# alcohol_consumption_per_week                   1             2             3
# physical_activity_minutes_per_week            45            73           158
# diet_score                                   7.7           5.7           8.5
# sleep_hours_per_day                          6.8           6.5           7.4
# screen_time_hours_per_day                    6.1           5.8           9.1
# bmi                                         33.4          23.8          24.1
# waist_to_hip_ratio                          0.93          0.83          0.83
# systolic_bp                                  112           120            95
# diastolic_bp                                  70            77            89
# heart_rate                                    62            71            73
# cholesterol_total                            199           199           188
# hdl_cholesterol                               58            50            59
# ldl_cholesterol                              114           121           114
# triglycerides                                102           124           108
# gender                                    Female        Female          Male
# ethnicity                               Hispanic         White      Hispanic
# education_level                       Highschool    Highschool    Highschool
# income_level                        Lower-Middle  Upper-Middle  Lower-Middle
# smoking_status                           Current         Never         Never
# employment_status                       Employed      Employed       Retired
# family_history_diabetes                        0             0             0
# hypertension_history                           0             0             0
# cardiovascular_history                         0             0             0
# diagnosed_diabetes                           1.0           1.0           0.0
#
#                                                3             4
# id                                             3             4
# age                                           54            54
# alcohol_consumption_per_week                   3             1
# physical_activity_minutes_per_week            77            55
# diet_score                                   4.6           5.7
# sleep_hours_per_day                          7.0           6.2
# screen_time_hours_per_day                    9.2           5.1
# bmi                                         26.6          28.8
# waist_to_hip_ratio                          0.83           0.9
# systolic_bp                                  121           108
# diastolic_bp                                  69            60
# heart_rate                                    74            85
# cholesterol_total                            182           206
# hdl_cholesterol                               54            49
# ldl_cholesterol                               85           131
# triglycerides                                123           124
# gender                                    Female          Male
# ethnicity                                  White         White
# education_level                       Highschool    Highschool
# income_level                        Lower-Middle  Upper-Middle
# smoking_status                           Current         Never
# employment_status                       Employed       Retired
# family_history_diabetes                        0             0
# hypertension_history                           1             1
# cardiovascular_history                         0             0
# diagnosed_diabetes                           1.0           1.0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   id                                  700000 non-null  int64
#  1   age                                 700000 non-null  int64
#  2   alcohol_consumption_per_week        700000 non-null  int64
#  3   physical_activity_minutes_per_week  700000 non-null  int64
#  4   diet_score                          700000 non-null  float64
#  5   sleep_hours_per_day                 700000 non-null  float64
#  6   screen_time_hours_per_day           700000 non-null  float64
#  7   bmi                                 700000 non-null  float64
#  8   waist_to_hip_ratio                  700000 non-null  float64
#  9   systolic_bp                         700000 non-null  int64
#  10  diastolic_bp                        700000 non-null  int64
#  11  heart_rate                          700000 non-null  int64
#  12  cholesterol_total                   700000 non-null  int64
#  13  hdl_cholesterol                     700000 non-null  int64
#  14  ldl_cholesterol                     700000 non-null  int64
#  15  triglycerides                       700000 non-null  int64
#  16  gender                              700000 non-null  object
#  17  ethnicity                           700000 non-null  object
#  18  education_level                     700000 non-null  object
#  19  income_level                        700000 non-null  object
#  20  smoking_status                      700000 non-null  object
#  21  employment_status                   700000 non-null  object
#  22  family_history_diabetes             700000 non-null  int64
#  23  hypertension_history                700000 non-null  int64
#  24  cardiovascular_history              700000 non-null  int64
#  25  diagnosed_diabetes                  700000 non-null  float64
# dtypes: float64(6), int64(14), object(6)
# memory usage: 138.9+ MB

# %% [markdown]
# - No null values in the data.
# - some columns with `object` dtype need conversion to float
# - object dtype columns are categorical attributes with multiple categories, while `family_history_diabetes`, `hypertension_history` and `cardiovascular_history` are binary categorical attributes already encoded as 0s and 1s.
# - drop the `id` column for input to the model.

# %%
train_data[['family_history_diabetes', 'hypertension_history', 'cardiovascular_history']].head()
# Out:
#    family_history_diabetes  hypertension_history  cardiovascular_history
# 0                        0                     0                       0
# 1                        0                     0                       0
# 2                        0                     0                       0
# 3                        0                     1                       0
# 4                        0                     1                       0

# %%
train_data.select_dtypes(object)
# Out:
#         gender ethnicity education_level  income_level smoking_status  \
# 0       Female  Hispanic      Highschool  Lower-Middle        Current
# 1       Female     White      Highschool  Upper-Middle          Never
# 2         Male  Hispanic      Highschool  Lower-Middle          Never
# 3       Female     White      Highschool  Lower-Middle        Current
# 4         Male     White      Highschool  Upper-Middle          Never
# ...        ...       ...             ...           ...            ...
# 699995  Female  Hispanic    Postgraduate  Upper-Middle         Former
# 699996  Female  Hispanic        Graduate  Upper-Middle         Former
# 699997  Female     White        Graduate        Middle          Never
# 699998  Female     White      Highschool  Lower-Middle          Never
# 699999  Female     Black        Graduate           Low         Former
#
#        employment_status
# 0               Employed
# 1               Employed
# 2                Retired
# 3               Employed
# 4                Retired
# ...                  ...
# 699995          Employed
# 699996          Employed
# 699997          Employed
# 699998           Retired
# 699999          Employed
#
# [700000 rows x 6 columns]

# %% [markdown]
# **Histograms:**

# %%
plt.rc('font', size=8)
train_data.iloc[np.random.randint(len(train_data), size=(50_000)), 1:16].hist(bins=50, figsize=(12, 8))
plt.show()

# %%
train_data.sample(50000).loc[train_data.physical_activity_minutes_per_week > 400].plot(x="physical_activity_minutes_per_week", y="diagnosed_diabetes", kind="scatter")
# Out:
# <Axes: xlabel='physical_activity_minutes_per_week', ylabel='diagnosed_diabetes'>

# %%
train_data.sample(50000).plot(x="age", y="diagnosed_diabetes", kind="scatter")
# Out:
# <Axes: xlabel='age', ylabel='diagnosed_diabetes'>

# %%
train_data.corr(numeric_only=True)['diagnosed_diabetes'].sort_values(ascending=False)
# Out:
# diagnosed_diabetes                    1.000000
# family_history_diabetes               0.211064
# age                                   0.161162
# systolic_bp                           0.107132
# bmi                                   0.105580
# ldl_cholesterol                       0.102771
# triglycerides                         0.090635
# cholesterol_total                     0.088112
# waist_to_hip_ratio                    0.081050
# diastolic_bp                          0.036271
# hypertension_history                  0.029979
# cardiovascular_history                0.024746
# heart_rate                            0.023865
# screen_time_hours_per_day             0.018213
# sleep_hours_per_day                   0.003509
# alcohol_consumption_per_week          0.002991
# id                                   -0.000075
# diet_score                           -0.050119
# hdl_cholesterol                      -0.053231
# physical_activity_minutes_per_week   -0.169789
# Name: diagnosed_diabetes, dtype: float64

# %%
train_data.corr(numeric_only=True)
# Out:
#                                           id       age  \
# id                                  1.000000  0.001615
# age                                 0.001615  1.000000
# alcohol_consumption_per_week        0.001614  0.003295
# physical_activity_minutes_per_week  0.012424 -0.029101
# diet_score                          0.000878 -0.001898
# sleep_hours_per_day                -0.002118 -0.001286
# screen_time_hours_per_day          -0.000716 -0.002313
# bmi                                -0.000692  0.062958
# waist_to_hip_ratio                 -0.000144  0.044654
# systolic_bp                         0.001546  0.502894
# diastolic_bp                       -0.000234  0.188403
# heart_rate                         -0.000764  0.004294
# cholesterol_total                   0.000518  0.283155
# hdl_cholesterol                    -0.000368  0.002654
# ldl_cholesterol                     0.000129  0.245503
# triglycerides                       0.001865  0.043605
# family_history_diabetes             0.000630  0.018417
# hypertension_history               -0.000883  0.177636
# cardiovascular_history              0.000729  0.099604
# diagnosed_diabetes                 -0.000075  0.161162
#
#                                     alcohol_consumption_per_week  \
# id                                                      0.001614
# age                                                     0.003295
# alcohol_consumption_per_week                            1.000000
# physical_activity_minutes_per_week                      0.003010
# diet_score                                              0.003284
# sleep_hours_per_day                                    -0.000351
# screen_time_hours_per_day                               0.004797
# bmi                                                    -0.017552
# waist_to_hip_ratio                                     -0.014716
# systolic_bp                                            -0.006472
# diastolic_bp                                           -0.001502
# heart_rate                                              0.002230
# cholesterol_total                                      -0.003121
# hdl_cholesterol                                         0.009062
# ldl_cholesterol                                        -0.006305
# triglycerides                                           0.099985
# family_history_diabetes                                 0.002069
# hypertension_history                                   -0.003983
# cardiovascular_history                                 -0.001566
# diagnosed_diabetes                                      0.002991
#
#                                     physical_activity_minutes_per_week  \
# id                                                            0.012424
# age                                                          -0.029101
# alcohol_consumption_per_week                                  0.003010
# physical_activity_minutes_per_week                            1.000000
# diet_score                                                    0.008466
# sleep_hours_per_day                                          -0.006900
# screen_time_hours_per_day                                     0.001754
# bmi                                                          -0.085086
# waist_to_hip_ratio                                           -0.067508
# systolic_bp                                                  -0.030908
# diastolic_bp                                                 -0.018341
# heart_rate                                                   -0.268426
# cholesterol_total                                            -0.027439
# hdl_cholesterol                                               0.015996
# ldl_cholesterol                                              -0.033272
# triglycerides                                                -0.045595
# family_history_diabetes                                      -0.035260
# hypertension_history                                         -0.005766
# cardiovascular_history                                       -0.002205
# diagnosed_diabetes                                           -0.169789
#
#                                     diet_score  sleep_hours_per_day  \
# id                                    0.000878            -0.002118
# age                                  -0.001898            -0.001286
# alcohol_consumption_per_week          0.003284            -0.000351
# physical_activity_minutes_per_week    0.008466            -0.006900
# diet_score                            1.000000             0.000882
# sleep_hours_per_day                   0.000882             1.000000
# screen_time_hours_per_day             0.000382             0.005965
# bmi                                  -0.198899             0.003380
# waist_to_hip_ratio                   -0.150906             0.000371
# systolic_bp                          -0.038676             0.003995
# diastolic_bp                         -0.028384             0.001457
# heart_rate                            0.005116             0.009711
# cholesterol_total                    -0.041622             0.001287
# hdl_cholesterol                       0.043585            -0.000549
# ldl_cholesterol                      -0.055908             0.001452
# triglycerides                        -0.101834            -0.005351
# family_history_diabetes              -0.005173             0.002502
# hypertension_history                  0.001112             0.005092
# cardiovascular_history                0.002690             0.002002
# diagnosed_diabetes                   -0.050119             0.003509
#
#                                     screen_time_hours_per_day       bmi  \
# id                                                  -0.000716 -0.000692
# age                                                 -0.002313  0.062958
# alcohol_consumption_per_week                         0.004797 -0.017552
# physical_activity_minutes_per_week                   0.001754 -0.085086
# diet_score                                           0.000382 -0.198899
# sleep_hours_per_day                                  0.005965  0.003380
# screen_time_hours_per_day                            1.000000  0.002758
# bmi                                                  0.002758  1.000000
# waist_to_hip_ratio                                   0.003393  0.757191
# systolic_bp                                          0.004276  0.225033
# diastolic_bp                                        -0.004632  0.143702
# heart_rate                                          -0.000152  0.009575
# cholesterol_total                                   -0.003384  0.180075
# hdl_cholesterol                                     -0.003529 -0.197702
# ldl_cholesterol                                     -0.000059  0.241057
# triglycerides                                        0.003124  0.443837
# family_history_diabetes                              0.004202  0.006417
# hypertension_history                                 0.001416  0.009471
# cardiovascular_history                               0.000836  0.003461
# diagnosed_diabetes                                   0.018213  0.105580
#
#                                     waist_to_hip_ratio  systolic_bp  \
# id                                           -0.000144     0.001546
# age                                           0.044654     0.502894
# alcohol_consumption_per_week                 -0.014716    -0.006472
# physical_activity_minutes_per_week           -0.067508    -0.030908
# diet_score                                   -0.150906    -0.038676
# sleep_hours_per_day                           0.000371     0.003995
# screen_time_hours_per_day                     0.003393     0.004276
# bmi                                           0.757191     0.225033
# waist_to_hip_ratio                            1.000000     0.171691
# systolic_bp                                   0.171691     1.000000
# diastolic_bp                                  0.111056     0.132916
# heart_rate                                    0.008807     0.005208
# cholesterol_total                             0.146030     0.196124
# hdl_cholesterol                              -0.154951    -0.039579
# ldl_cholesterol                               0.193638     0.187003
# triglycerides                                 0.359802     0.125682
# family_history_diabetes                       0.004509     0.009284
# hypertension_history                          0.006384     0.093637
# cardiovascular_history                        0.000885     0.052653
# diagnosed_diabetes                            0.081050     0.107132
#
#                                     diastolic_bp  heart_rate  \
# id                                     -0.000234   -0.000764
# age                                     0.188403    0.004294
# alcohol_consumption_per_week           -0.001502    0.002230
# physical_activity_minutes_per_week     -0.018341   -0.268426
# diet_score                             -0.028384    0.005116
# sleep_hours_per_day                     0.001457    0.009711
# screen_time_hours_per_day              -0.004632   -0.000152
# bmi                                     0.143702    0.009575
# waist_to_hip_ratio                      0.111056    0.008807
# systolic_bp                             0.132916    0.005208
# diastolic_bp                            1.000000    0.003055
# heart_rate                              0.003055    1.000000
# cholesterol_total                       0.075185   -0.002083
# hdl_cholesterol                        -0.025440   -0.013209
# ldl_cholesterol                         0.075297    0.005770
# triglycerides                           0.069475    0.001857
# family_history_diabetes                 0.003912    0.007484
# hypertension_history                    0.036673    0.000452
# cardiovascular_history                  0.016763    0.002637
# diagnosed_diabetes                      0.036271    0.023865
#
#                                     cholesterol_total  hdl_cholesterol  \
# id                                           0.000518        -0.000368
# age                                          0.283155         0.002654
# alcohol_consumption_per_week                -0.003121         0.009062
# physical_activity_minutes_per_week          -0.027439         0.015996
# diet_score                                  -0.041622         0.043585
# sleep_hours_per_day                          0.001287        -0.000549
# screen_time_hours_per_day                   -0.003384        -0.003529
# bmi                                          0.180075        -0.197702
# waist_to_hip_ratio                           0.146030        -0.154951
# systolic_bp                                  0.196124        -0.039579
# diastolic_bp                                 0.075185        -0.025440
# heart_rate                                  -0.002083        -0.013209
# cholesterol_total                            1.000000         0.055017
# hdl_cholesterol                              0.055017         1.000000
# ldl_cholesterol                              0.805909        -0.375791
# triglycerides                                0.100834        -0.095271
# family_history_diabetes                      0.010208        -0.010868
# hypertension_history                         0.051344        -0.000447
# cardiovascular_history                       0.028395         0.000152
# diagnosed_diabetes                           0.088112        -0.053231
#
#                                     ldl_cholesterol  triglycerides  \
# id                                         0.000129       0.001865
# age                                        0.245503       0.043605
# alcohol_consumption_per_week              -0.006305       0.099985
# physical_activity_minutes_per_week        -0.033272      -0.045595
# diet_score                                -0.055908      -0.101834
# sleep_hours_per_day                        0.001452      -0.005351
# screen_time_hours_per_day                 -0.000059       0.003124
# bmi                                        0.241057       0.443837
# waist_to_hip_ratio                         0.193638       0.359802
# systolic_bp                                0.187003       0.125682
# diastolic_bp                               0.075297       0.069475
# heart_rate                                 0.005770       0.001857
# cholesterol_total                          0.805909       0.100834
# hdl_cholesterol                           -0.375791      -0.095271
# ldl_cholesterol                            1.000000       0.131343
# triglycerides                              0.131343       1.000000
# family_history_diabetes                    0.014129       0.014825
# hypertension_history                       0.045771       0.007943
# cardiovascular_history                     0.021442       0.006697
# diagnosed_diabetes                         0.102771       0.090635
#
#                                     family_history_diabetes  \
# id                                                 0.000630
# age                                                0.018417
# alcohol_consumption_per_week                       0.002069
# physical_activity_minutes_per_week                -0.035260
# diet_score                                        -0.005173
# sleep_hours_per_day                                0.002502
# screen_time_hours_per_day                          0.004202
# bmi                                                0.006417
# waist_to_hip_ratio                                 0.004509
# systolic_bp                                        0.009284
# diastolic_bp                                       0.003912
# heart_rate                                         0.007484
# cholesterol_total                                  0.010208
# hdl_cholesterol                                   -0.010868
# ldl_cholesterol                                    0.014129
# triglycerides                                      0.014825
# family_history_diabetes                            1.000000
# hypertension_history                               0.008302
# cardiovascular_history                             0.002352
# diagnosed_diabetes                                 0.211064
#
#                                     hypertension_history  \
# id                                             -0.000883
# age                                             0.177636
# alcohol_consumption_per_week                   -0.003983
# physical_activity_minutes_per_week             -0.005766
# diet_score                                      0.001112
# sleep_hours_per_day                             0.005092
# screen_time_hours_per_day                       0.001416
# bmi                                             0.009471
# waist_to_hip_ratio                              0.006384
# systolic_bp                                     0.093637
# diastolic_bp                                    0.036673
# heart_rate                                      0.000452
# cholesterol_total                               0.051344
# hdl_cholesterol                                -0.000447
# ldl_cholesterol                                 0.045771
# triglycerides                                   0.007943
# family_history_diabetes                         0.008302
# hypertension_history                            1.000000
# cardiovascular_history                          0.012262
# diagnosed_diabetes                              0.029979
#
#                                     cardiovascular_history  diagnosed_diabetes
# id                                                0.000729           -0.000075
# age                                               0.099604            0.161162
# alcohol_consumption_per_week                     -0.001566            0.002991
# physical_activity_minutes_per_week               -0.002205           -0.169789
# diet_score                                        0.002690           -0.050119
# sleep_hours_per_day                               0.002002            0.003509
# screen_time_hours_per_day                         0.000836            0.018213
# bmi                                               0.003461            0.105580
# waist_to_hip_ratio                                0.000885            0.081050
# systolic_bp                                       0.052653            0.107132
# diastolic_bp                                      0.016763            0.036271
# heart_rate                                        0.002637            0.023865
# cholesterol_total                                 0.028395            0.088112
# hdl_cholesterol                                   0.000152           -0.053231
# ldl_cholesterol                                   0.021442            0.102771
# triglycerides                                     0.006697            0.090635
# family_history_diabetes                           0.002352            0.211064
# hypertension_history                              0.012262            0.029979
# cardiovascular_history                            1.000000            0.024746
# diagnosed_diabetes                                0.024746            1.000000

# %% [markdown]
# - high correlation between bmi and triglycerides
# - high correlation between bmi and waist-to-hip ratio
# - high correlation between systolic bp and age
# - high correlation between cholesterol_total and Idl_cholesterol

# %% [markdown]
# ## Create test set

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data.drop("diagnosed_diabetes", axis=1), train_data["diagnosed_diabetes"],
                                                    test_size=.15, random_state=42)
X_train = X_train.drop('id', axis=1)
X_test = X_test.drop('id', axis=1)

# %%
y_train.value_counts(normalize=True)
# unbalanced dataset but the positive class is not rare, its the negative class which is rare.
# Out:
# diagnosed_diabetes
# 1.0    0.623003
# 0.0    0.376997
# Name: proportion, dtype: float64

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer, make_column_selector

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
def combined_historical_attributes(X):
    return X.sum(axis=1).reshape(-1, 1)

# %%
num_pipeline = make_pipeline(SimpleImputer(strategy="median"), StandardScaler())
cat_pipeline_1 = make_pipeline(SimpleImputer(strategy="most_frequent"), OneHotEncoder(handle_unknown="ignore"))
cat_pipeline_2 = make_pipeline(SimpleImputer(strategy="most_frequent"), OrdinalEncoder(handle_unknown="error"))
# cat_pipeline_3 = make_pipeline(SimpleImputer(strategy="most_frequent"), FunctionTransformer(combined_historical_attributes))

preprocessing_pipeline = make_column_transformer(
    (num_pipeline, ['age', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'diet_score', 'sleep_hours_per_day', 'screen_time_hours_per_day',
                    'bmi', 'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol', 'triglycerides']),
    (cat_pipeline_1, ['gender', 'ethnicity', 'smoking_status', 'employment_status']),
    (cat_pipeline_2, ['education_level', 'income_level']),
    (SimpleImputer(strategy="most_frequent"), ['family_history_diabetes', 'hypertension_history', 'cardiovascular_history']),
    remainder='drop'
)

# %%
preprocessing_pipeline
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['age', 'alcohol_consumption_per_week',
#                                   'physical_activity_minutes_per_week',
#                                   'diet_score', 'sleep_hours_per_day',
#                                   'screen_time_hours_per_day', 'bmi',
#                                   'waist_to_hip_ratio', 'systolic_bp',
#                                   'diastolic_bp', 'hear...
#                                  ['gender', 'ethnicity', 'smoking_status',
#                                   'employment_status']),
#                                 ('pipeline-3',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder())]),
#                                  ['education_level', 'income_level']),
#                                 ('simpleimputer',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['family_history_diabetes',
#                                   'hypertension_history',
#                                   'cardiovascular_history'])])

# %% [markdown]
# Overall, have tried reducing the dimensionality of the data this time.

# %% [markdown]
# ### Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
log_reg = make_pipeline(preprocessing_pipeline, LogisticRegression())

# %%
log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['age',
#                                                    'alcohol_consumption_per_week',
#                                                    'physical_activity_minutes_per_week',
#                                                    'diet_score',
#                                                    'sleep_hours_per_day',
#                                                    'screen_time_hours_per_day',
#                                                    'bmi', 'waist_to_hip_rati...
#                                                    'employment_status']),
#                                                  ('pipeline-3',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['education_level',
#                                                    'income_level']),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   ['family_history_diabetes',
#                                                    'hypertension_history',
#                                                    'cardiovascular_history'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
y_pred_prob_log_reg = log_reg.predict_proba(X_test)

# %%
from sklearn.metrics import recall_score, precision_score, roc_auc_score, accuracy_score, roc_curve

# %%
recall_score(y_test, y_pred_prob_log_reg[:, 1] > 0.5)
# Out:
# 0.8642639439195368

# %%
roc_auc_score(y_test, y_pred_prob_log_reg[:, 1])
# Out:
# 0.693009084423313

# %%
rf = make_pipeline(preprocessing_pipeline, RandomForestClassifier(n_estimators=500, min_samples_leaf=5000))
rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['age',
#                                                    'alcohol_consumption_per_week',
#                                                    'physical_activity_minutes_per_week',
#                                                    'diet_score',
#                                                    'sleep_hours_per_day',
#                                                    'screen_time_hours_per_day',
#                                                    'bmi', 'waist_to_hip_rati...
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['education_level',
#                                                    'income_level']),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   ['family_history_diabetes',
#                                                    'hypertension_history',
#                                                    'cardiovascular_history'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(min_samples_leaf=5000,
#                                         n_estimators=500))])

# %%
y_pred_prob_rf = rf.predict_proba(X_test)

# %%
recall_score(y_test, y_pred_prob_rf[:, 1] > 0.5)
# Out:
# 0.9556385248399878

# %%
roc_auc_score(y_test, y_pred_prob_rf[:, 1])
# Out:
# 0.6904650109306255

# %%
accuracy_score(y_test, y_pred_prob_rf[:, 1] > 0.5)
# Out:
# 0.6478095238095238

# %%
accuracy_score(y_train, rf.predict(X_train))
# Out:
# 0.6485647058823529

# %% [markdown]
# **.**

# %%
rf = make_pipeline(preprocessing_pipeline, RandomForestClassifier(n_estimators=500, min_samples_leaf=5000, random_state=42))
rf.fit(train_data.drop("diagnosed_diabetes", axis=1), train_data["diagnosed_diabetes"])
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['age',
#                                                    'alcohol_consumption_per_week',
#                                                    'physical_activity_minutes_per_week',
#                                                    'diet_score',
#                                                    'sleep_hours_per_day',
#                                                    'screen_time_hours_per_day',
#                                                    'bmi', 'waist_to_hip_rati...
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinalencoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['education_level',
#                                                    'income_level']),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   ['family_history_diabetes',
#                                                    'hypertension_history',
#                                                    'cardiovascular_history'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(min_samples_leaf=5000, n_estimators=500,
#                                         random_state=42))])

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
gbrt_classifier = make_pipeline(preprocessing_pipeline, GradientBoostingClassifier())

# %%
gbrt_classifier.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     ['age', 'alcohol_consumption_per_week',
#                                      'physical_activity_minutes_per_week',
#                                      'diet_score', 'sleep_hours_per_day',
#                                      'screen_time_hours_per_day', 'bmi',
#                                      'waist_to_hip_ratio', 'systolic_bp',
#                                      'diastolic_bp', 'hear...
#                                     ['gender', 'ethnicity', 'smoking_status',
#                                      'employment_status']),
#                                    ('pipeline-3',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('ordinalencoder',
#                                                      OrdinalEncoder())]),
#                                     ['education_level', 'income_level']),
#                                    ('simpleimputer',
#                                     SimpleImputer(strategy='most_frequent'),
#                                     ['family_history_diabetes',
#                                      'hypertension_history',
#                                      'cardiovascular_history'])])),
#   ('gradientboostingclassifier', GradientBoostingClassifier())],
#  'transform_input': None,
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   ['age', 'alcohol_consumption_per_week',
#                                    'physical_activity_minutes_per_week',
#                                    'diet_score', 'sleep_hours_per_day',
#                                    'screen_time_hours_per_day', 'bmi',
#                                    'waist_to_hip_ratio', 'systolic_bp',
#                                    'diastolic_bp', 'hear...
#                                   ['gender', 'ethnicity', 'smoking_status',
#                                    'employment_status']),
#                                  ('pipeline-3',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('ordinalencoder',
#                                                    OrdinalEncoder())]),
#                                   ['education_level', 'income_level']),
#                                  ('simpleimputer',
#                                   SimpleImputer(strategy='most_frequent'),
#                                   ['family_history_diabetes',
#                                    'hypertension_history',
#                                    'cardiovascular_history'])]),
#  'gradientboostingclassifier': GradientBoostingClassifier(),
#  'columntransformer__force_int_remainder_cols': 'deprecated',
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                    ('standardscaler', StandardScaler())]),
#    ['age',
#     'alcohol_consumption_per_week',
#     'physical_activity_minutes_per_week',
#     'diet_score',
#     'sleep_hours_per_day',
#     'screen_time_hours_per_day',
#     'bmi',
#     'waist_to_hip_ratio',
#     'systolic_bp',
#     'diastolic_bp',
#     'heart_rate',
#     'cholesterol_total',
#     'hdl_cholesterol',
#     'ldl_cholesterol',
#     'triglycerides']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#    ['gender', 'ethnicity', 'smoking_status', 'employment_status']),
#   ('pipeline-3',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('ordinalencoder', OrdinalEncoder())]),
#    ['education_level', 'income_level']),
#   ('simpleimputer',
#    SimpleImputer(strategy='most_frequent'),
#    ['family_history_diabetes',
#     'hypertension_history',
#     'cardiovascular_history'])],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#  'columntransformer__pipeline-3': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('ordinalencoder', OrdinalEncoder())]),
#  'columntransformer__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-1__memory': None,
#  'columntransformer__pipeline-1__steps': [('simpleimputer',
#    SimpleImputer(strategy='median')),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline-1__transform_input': None,
#  'columntransformer__pipeline-1__verbose': False,
#  'columntransformer__pipeline-1__simpleimputer': SimpleImputer(strategy='median'),
#  'columntransformer__pipeline-1__standardscaler': StandardScaler(),
#  'columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-1__simpleimputer__copy': True,
#  'columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-1__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-1__simpleimputer__strategy': 'median',
#  'columntransformer__pipeline-1__standardscaler__copy': True,
#  'columntransformer__pipeline-1__standardscaler__with_mean': True,
#  'columntransformer__pipeline-1__standardscaler__with_std': True,
#  'columntransformer__pipeline-2__memory': None,
#  'columntransformer__pipeline-2__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))],
#  'columntransformer__pipeline-2__transform_input': None,
#  'columntransformer__pipeline-2__verbose': False,
#  'columntransformer__pipeline-2__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-2__onehotencoder': OneHotEncoder(handle_unknown='ignore'),
#  'columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-2__simpleimputer__copy': True,
#  'columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-2__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-2__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-2__onehotencoder__categories': 'auto',
#  'columntransformer__pipeline-2__onehotencoder__drop': None,
#  'columntransformer__pipeline-2__onehotencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-2__onehotencoder__feature_name_combiner': 'concat',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown': 'ignore',
#  'columntransformer__pipeline-2__onehotencoder__max_categories': None,
#  'columntransformer__pipeline-2__onehotencoder__min_frequency': None,
#  'columntransformer__pipeline-2__onehotencoder__sparse_output': True,
#  'columntransformer__pipeline-3__memory': None,
#  'columntransformer__pipeline-3__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('ordinalencoder', OrdinalEncoder())],
#  'columntransformer__pipeline-3__transform_input': None,
#  'columntransformer__pipeline-3__verbose': False,
#  'columntransformer__pipeline-3__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-3__ordinalencoder': OrdinalEncoder(),
#  'columntransformer__pipeline-3__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-3__simpleimputer__copy': True,
#  'columntransformer__pipeline-3__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-3__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline-3__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-3__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-3__ordinalencoder__categories': 'auto',
#  'columntransformer__pipeline-3__ordinalencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-3__ordinalencoder__encoded_missing_value': nan,
#  'columntransformer__pipeline-3__ordinalencoder__handle_unknown': 'error',
#  'columntransformer__pipeline-3__ordinalencoder__max_categories': None,
#  'columntransformer__pipeline-3__ordinalencoder__min_frequency': None,
#  'columntransformer__pipeline-3__ordinalencoder__unknown_value': None,
#  'columntransformer__simpleimputer__add_indicator': False,
#  'columntransformer__simpleimputer__copy': True,
#  'columntransformer__simpleimputer__fill_value': None,
#  'columntransformer__simpleimputer__keep_empty_features': False,
#  'columntransformer__simpleimputer__missing_values': nan,
#  'columntransformer__simpleimputer__strategy': 'most_frequent',
#  'gradientboostingclassifier__ccp_alpha': 0.0,
#  'gradientboostingclassifier__criterion': 'friedman_mse',
#  'gradientboostingclassifier__init': None,
#  'gradientboostingclassifier__learning_rate': 0.1,
#  'gradientboostingclassifier__loss': 'log_loss',
#  'gradientboostingclassifier__max_depth': 3,
#  'gradientboostingclassifier__max_features': None,
#  'gradientboostingclassifier__max_leaf_nodes': None,
#  'gradientboostingclassifier__min_impurity_decrease': 0.0,
#  'gradientboostingclassifier__min_samples_leaf': 1,
#  'gradientboostingclassifier__min_samples_split': 2,
#  'gradientboostingclassifier__min_weight_fraction_leaf': 0.0,
#  'gradientboostingclassifier__n_estimators': 100,
#  'gradientboostingclassifier__n_iter_no_change': None,
#  'gradientboostingclassifier__random_state': None,
#  'gradientboostingclassifier__subsample': 1.0,
#  'gradientboostingclassifier__tol': 0.0001,
#  'gradientboostingclassifier__validation_fraction': 0.1,
#  'gradientboostingclassifier__verbose': 0,
#  'gradientboostingclassifier__warm_start': False}

# %%
param_grid = [{
    'gradientboostingclassifier__max_depth': [3, 5, 15],
    'gradientboostingclassifier__max_features': [3, 5, 7],
    'gradientboostingclassifier__n_estimators': [50, 100, 300]
}]
grid_search = GridSearchCV(gbrt_classifier, param_grid=param_grid, cv=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          ['age',
#                                                                           'alcohol_consumption_per_week',
#                                                                           'physical_activity_minutes_per_week',
#                                                                           'diet_score',
#                                                                           'sleep_hours_per_day',
#                                                                           'screen_time_hours_per_d...
#                                                                          SimpleImputer(strategy='most_frequent'),
#                                                                          ['family_history_diabetes',
#                                                                           'hypertension_history',
#                                                                           'cardiovascular_history'])])),
#                                        ('gradientboostingclassifier',
#                                         GradientBoostingClassifier())]),
#              param_grid=[{'gradientboostingclassifier__max_depth': [3, 5, 15],
#                           'gradientboostingclassifier__max_features': [3, 5, 7],
#                           'gradientboostingclassifier__n_estimators': [50, 100,
#                                                                        300]}])

# %%
gbrt_best = grid_search.best_estimator_

# %%
y_pred_prob_gbrt_best = gbrt_best.predict_proba(X_test)
roc_auc_score(y_test, y_pred_prob_rf[:, 1])
# Out:
# 0.6904650109306255

# %%
np.round(np.sort(gbrt_best[-1].feature_importances_), 4)
# Out:
# array([1.000e-04, 2.000e-04, 2.000e-04, 2.000e-04, 2.000e-04, 2.000e-04,
#        3.000e-04, 3.000e-04, 3.000e-04, 3.000e-04, 3.000e-04, 3.000e-04,
#        3.000e-04, 4.000e-04, 5.000e-04, 8.000e-04, 1.000e-03, 1.300e-03,
#        1.400e-03, 1.600e-03, 3.800e-03, 4.700e-03, 7.100e-03, 1.090e-02,
#        1.230e-02, 1.400e-02, 1.520e-02, 1.790e-02, 2.880e-02, 3.090e-02,
#        3.460e-02, 5.770e-02, 1.488e-01, 2.980e-01, 3.054e-01])

# %%
list(zip(np.round(gbrt_best[-1].feature_importances_, 4), gbrt_best[0].get_feature_names_out()))
# Out:
# [(np.float64(0.1488), 'pipeline-1__age'),
#  (np.float64(0.0016), 'pipeline-1__alcohol_consumption_per_week'),
#  (np.float64(0.3054), 'pipeline-1__physical_activity_minutes_per_week'),
#  (np.float64(0.014), 'pipeline-1__diet_score'),
#  (np.float64(0.0038), 'pipeline-1__sleep_hours_per_day'),
#  (np.float64(0.0071), 'pipeline-1__screen_time_hours_per_day'),
#  (np.float64(0.0346), 'pipeline-1__bmi'),
#  (np.float64(0.0152), 'pipeline-1__waist_to_hip_ratio'),
#  (np.float64(0.0288), 'pipeline-1__systolic_bp'),
#  (np.float64(0.0047), 'pipeline-1__diastolic_bp'),
#  (np.float64(0.0109), 'pipeline-1__heart_rate'),
#  (np.float64(0.0179), 'pipeline-1__cholesterol_total'),
#  (np.float64(0.0123), 'pipeline-1__hdl_cholesterol'),
#  (np.float64(0.0309), 'pipeline-1__ldl_cholesterol'),
#  (np.float64(0.0577), 'pipeline-1__triglycerides'),
#  (np.float64(0.0002), 'pipeline-2__gender_Female'),
#  (np.float64(0.0003), 'pipeline-2__gender_Male'),
#  (np.float64(0.0003), 'pipeline-2__gender_Other'),
#  (np.float64(0.0002), 'pipeline-2__ethnicity_Asian'),
#  (np.float64(0.0002), 'pipeline-2__ethnicity_Black'),
#  (np.float64(0.0005), 'pipeline-2__ethnicity_Hispanic'),
#  (np.float64(0.0003), 'pipeline-2__ethnicity_Other'),
#  (np.float64(0.0003), 'pipeline-2__ethnicity_White'),
#  (np.float64(0.0003), 'pipeline-2__smoking_status_Current'),
#  (np.float64(0.0003), 'pipeline-2__smoking_status_Former'),
#  (np.float64(0.0001), 'pipeline-2__smoking_status_Never'),
#  (np.float64(0.0002), 'pipeline-2__employment_status_Employed'),
#  (np.float64(0.0004), 'pipeline-2__employment_status_Retired'),
#  (np.float64(0.0002), 'pipeline-2__employment_status_Student'),
#  (np.float64(0.0003), 'pipeline-2__employment_status_Unemployed'),
#  (np.float64(0.001), 'pipeline-3__education_level'),
#  (np.float64(0.0013), 'pipeline-3__income_level'),
#  (np.float64(0.298), 'simpleimputer__family_history_diabetes'),
#  (np.float64(0.0008), 'simpleimputer__hypertension_history'),
#  (np.float64(0.0014), 'simpleimputer__cardiovascular_history')]

# %%
grid_search.best_params_
# Out:
# {'gradientboostingclassifier__max_depth': 5,
#  'gradientboostingclassifier__max_features': 7,
#  'gradientboostingclassifier__n_estimators': 300}

# %% [markdown]
# ## Submission output

# %%
def submission_output(estimator, test_data, file_name):
    test_set_predictions = estimator.predict_proba(test_data)[:, 1]
    test_data["diagnosed_diabetes"] = test_set_predictions
    test_data[["id", "diagnosed_diabetes"]].to_csv(file_name, index=False)

# %%
# submission_output(log_reg, "01_log_reg_3_variables.csv")

# %%
submission_output(rf, test_data, "07_gbrt_train_data_gridsearched.csv")

# %% [markdown]
# ---

# %% [markdown]
# - roc curve
